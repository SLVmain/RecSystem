# %% [markdown]
# # ITMO
# # Проект 3
# # Рекомендательные системы
#
# ## Двухуровневая модель рекомендаций на основе lightGBM

# %%
# !pip install implicit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: implicit in /usr/local/lib/python3.7/dist-packages (0.6.1)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.7/dist-packages (from implicit) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from implicit) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from implicit) (4.64.1)

# %%
# !git clone https://github.com/SLVmain/Recsystem.git
# Out:
# fatal: destination path 'Recsystem' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Для работы с матрицами
from scipy.sparse import csr_matrix

# Матричная факторизация
from implicit import als

# Модель второго уровня
from lightgbm import LGBMClassifier

import os, sys
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

# Написанные функции
from Recsystem.src.metrics import precision_at_k, recall_at_k
from Recsystem.src.utils import prefilter_items
from Recsystem.src.recommenders import MainRecommender
# Out:
# /usr/local/lib/python3.7/dist-packages/implicit/gpu/__init__.py:14: UserWarning: CUDA extension is built, but disabling GPU support because of 'Cuda Error: no CUDA-capable device is detected (/project/./implicit/gpu/utils.h:71)'
#   f"CUDA extension is built, but disabling GPU support because of '{e}'",

# %%
#download data from yandex disk
# !wget -O retail_train.csv https://getfile.dokpub.com/yandex/get/https://disk.yandex.ru/d/7zzy7loLn1mydA
# !wget -O hh_demographic.csv https://getfile.dokpub.com/yandex/get/https://disk.yandex.ru/d/K5QgI5i7b9OCAg
# !wget -O product.csv https://getfile.dokpub.com/yandex/get/https://disk.yandex.ru/d/YGMKawk5FPzM4w
# Out:
# --2022-11-09 20:29:23--  https://getfile.dokpub.com/yandex/get/https://disk.yandex.ru/d/7zzy7loLn1mydA
# Resolving getfile.dokpub.com (getfile.dokpub.com)... 142.132.255.217
# Connecting to getfile.dokpub.com (getfile.dokpub.com)|142.132.255.217|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://downloader.disk.yandex.ru/disk/6ec323c28d01ca1825a37477ea0f88cf4053957cb2041b99d15c71c68921e922/636c35ce/MNC-wvHOfDa0WFpeCBXdEeTllmFbRsuqTtMMo1bAHYmfZm06wNwADVaeVBrd1O94hx1t7mR55BRS-gIuH7IQKQ%3D%3D?uid=0&filename=retail_train.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZA0WPJn1sgCtV3OoRP2vKRXBZcMYaV5bIqW9uckUJx3GRAX03HPYQxcN%2B1YRYcCtZw%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=143477004&hid=d107c6346479d71567899d724067670c&media_type=spreadsheet&tknv=v2 [following]
# --2022-11-09 20:29:24--  https://downloader.disk.yandex.ru/disk/6ec323c28d01ca1825a37477ea0f88cf4053957cb2041b99d15c71c68921e922/636c35ce/MNC-wvHOfDa0WFpeCBXdEeTllmFbRsuqTtMMo1bAHYmfZm06wNwADVaeVBrd1O94hx1t7mR55BRS-gIuH7IQKQ%3D%3D?uid=0&filename=retail_train.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZA0WPJn1sgCtV3OoRP2vKRXBZcMYaV5bIqW9uckUJx3GRAX03HPYQxcN%2B1YRYcCtZw%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=143477004&hid=d107c6346479d71567899d724067670c&media_type=spreadsheet&tknv=v2
# Resolving downloader.disk.yandex.ru (downloader.disk.yandex.ru)... 77.88.21.127, 2a02:6b8::2:127
# Connecting to downloader.disk.yandex.ru (downloader.disk.yandex.ru)|77.88.21.127|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s358vla.storage.yandex.net/rdisk/6ec323c28d01ca1825a37477ea0f88cf4053957cb2041b99d15c71c68921e922/636c35ce/MNC-wvHOfDa0WFpeCBXdEeTllmFbRsuqTtMMo1bAHYmfZm06wNwADVaeVBrd1O94hx1t7mR55BRS-gIuH7IQKQ==?uid=0&filename=retail_train.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZA0WPJn1sgCtV3OoRP2vKRXBZcMYaV5bIqW9uckUJx3GRAX03HPYQxcN%2B1YRYcCtZw%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=143477004&hid=d107c6346479d71567899d724067670c&media_type=spreadsheet&tknv=v2&rtoken=Kbx0FZjZzZAm&force_default=no&ycrid=na-f48b072ed7ba9cce3d11242ae1023f2b-downloader11f&ts=5ed11e7fe8f80&s=76bb726820d31235553a88ed8679649b533adb592c04088d4ae52b4bbe22a0b5&pb=U2FsdGVkX1-ZUyZQhdmWJGLajjLpKA58Xc_VWVZ7G8yAaKZOzWaG89yWAFz4Tj444nWXxrOt49hfX-gC9KVwI-HBba6fiV7DGM75_Bu6dp0 [following]
# --2022-11-09 20:29:25--  https://s358vla.storage.yandex.net/rdisk/6ec323c28d01ca1825a37477ea0f88cf4053957cb2041b99d15c71c68921e922/636c35ce/MNC-wvHOfDa0WFpeCBXdEeTllmFbRsuqTtMMo1bAHYmfZm06wNwADVaeVBrd1O94hx1t7mR55BRS-gIuH7IQKQ==?uid=0&filename=retail_train.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZA0WPJn1sgCtV3OoRP2vKRXBZcMYaV5bIqW9uckUJx3GRAX03HPYQxcN%2B1YRYcCtZw%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=143477004&hid=d107c6346479d71567899d724067670c&media_type=spreadsheet&tknv=v2&rtoken=Kbx0FZjZzZAm&force_default=no&ycrid=na-f48b072ed7ba9cce3d11242ae1023f2b-downloader11f&ts=5ed11e7fe8f80&s=76bb726820d31235553a88ed8679649b533adb592c04088d4ae52b4bbe22a0b5&pb=U2FsdGVkX1-ZUyZQhdmWJGLajjLpKA58Xc_VWVZ7G8yAaKZOzWaG89yWAFz4Tj444nWXxrOt49hfX-gC9KVwI-HBba6fiV7DGM75_Bu6dp0
# Resolving s358vla.storage.yandex.net (s358vla.storage.yandex.net)... 141.8.128.82, 2a02:6b8:c0e:acb:0:41af:e7fd:ec6d
# Connecting to s358vla.storage.yandex.net (s358vla.storage.yandex.net)|141.8.128.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143477004 (137M) [text/plain]
# Saving to: ‘retail_train.csv’
#
# retail_train.csv    100%[===================>] 136.83M  18.3MB/s    in 8.7s
#
# 2022-11-09 20:29:34 (15.7 MB/s) - ‘retail_train.csv’ saved [143477004/143477004]
#
# --2022-11-09 20:29:35--  https://getfile.dokpub.com/yandex/get/https://disk.yandex.ru/d/K5QgI5i7b9OCAg
# Resolving getfile.dokpub.com (getfile.dokpub.com)... 142.132.255.217
# Connecting to getfile.dokpub.com (getfile.dokpub.com)|142.132.255.217|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://downloader.disk.yandex.ru/disk/3b2a7efa89c6748c8da5c850110613b571e9e511861694588e3537a627ab5fad/636c35d9/MNC-wvHOfDa0WFpeCBXdEQ3d9g4VqSFRDTu4KlcyeEk-432XrFsgclTccOFzVhLTZg-Wp-CGVE5o74nJHoeS5Q%3D%3D?uid=0&filename=hh_demographic.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZDOizWfkf%2Bbrb5xWhbMwP5XZd5B3OJhoVr20APdCtyJflsg4VIaLrfRKbQetv4dueQ%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=44349&hid=60a117e7de7176b2aed289ff77429316&media_type=spreadsheet&tknv=v2 [following]
# --2022-11-09 20:29:35--  https://downloader.disk.yandex.ru/disk/3b2a7efa89c6748c8da5c850110613b571e9e511861694588e3537a627ab5fad/636c35d9/MNC-wvHOfDa0WFpeCBXdEQ3d9g4VqSFRDTu4KlcyeEk-432XrFsgclTccOFzVhLTZg-Wp-CGVE5o74nJHoeS5Q%3D%3D?uid=0&filename=hh_demographic.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZDOizWfkf%2Bbrb5xWhbMwP5XZd5B3OJhoVr20APdCtyJflsg4VIaLrfRKbQetv4dueQ%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=44349&hid=60a117e7de7176b2aed289ff77429316&media_type=spreadsheet&tknv=v2
# Resolving downloader.disk.yandex.ru (downloader.disk.yandex.ru)... 77.88.21.127, 2a02:6b8::2:127
# Connecting to downloader.disk.yandex.ru (downloader.disk.yandex.ru)|77.88.21.127|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s338vla.storage.yandex.net/rdisk/3b2a7efa89c6748c8da5c850110613b571e9e511861694588e3537a627ab5fad/636c35d9/MNC-wvHOfDa0WFpeCBXdEQ3d9g4VqSFRDTu4KlcyeEk-432XrFsgclTccOFzVhLTZg-Wp-CGVE5o74nJHoeS5Q==?uid=0&filename=hh_demographic.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZDOizWfkf%2Bbrb5xWhbMwP5XZd5B3OJhoVr20APdCtyJflsg4VIaLrfRKbQetv4dueQ%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=44349&hid=60a117e7de7176b2aed289ff77429316&media_type=spreadsheet&tknv=v2&rtoken=AsrcRJf5PwKl&force_default=no&ycrid=na-b8225d4a998754e9aaabde8eb78eb43b-downloader23h&ts=5ed11e8a66840&s=0dca8cd9de2bf6ecf941ce97ed05393c9aa6446228b9b3f7536ec7253d3ef93c&pb=U2FsdGVkX19QPozqESOGcDDdpyZQfzu_xI8tQyuexadPnzLFH_mTW6NgwF9aaWXAoPSO_n7nrXzhniFks87i27SkO3PZ_q6s5o_iA9ifD_E [following]
# --2022-11-09 20:29:36--  https://s338vla.storage.yandex.net/rdisk/3b2a7efa89c6748c8da5c850110613b571e9e511861694588e3537a627ab5fad/636c35d9/MNC-wvHOfDa0WFpeCBXdEQ3d9g4VqSFRDTu4KlcyeEk-432XrFsgclTccOFzVhLTZg-Wp-CGVE5o74nJHoeS5Q==?uid=0&filename=hh_demographic.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZDOizWfkf%2Bbrb5xWhbMwP5XZd5B3OJhoVr20APdCtyJflsg4VIaLrfRKbQetv4dueQ%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=44349&hid=60a117e7de7176b2aed289ff77429316&media_type=spreadsheet&tknv=v2&rtoken=AsrcRJf5PwKl&force_default=no&ycrid=na-b8225d4a998754e9aaabde8eb78eb43b-downloader23h&ts=5ed11e8a66840&s=0dca8cd9de2bf6ecf941ce97ed05393c9aa6446228b9b3f7536ec7253d3ef93c&pb=U2FsdGVkX19QPozqESOGcDDdpyZQfzu_xI8tQyuexadPnzLFH_mTW6NgwF9aaWXAoPSO_n7nrXzhniFks87i27SkO3PZ_q6s5o_iA9ifD_E
# Resolving s338vla.storage.yandex.net (s338vla.storage.yandex.net)... 77.88.56.214, 2a02:6b8:c0e:9cc:0:41af:b089:271d
# Connecting to s338vla.storage.yandex.net (s338vla.storage.yandex.net)|77.88.56.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44349 (43K) [text/plain]
# Saving to: ‘hh_demographic.csv’
#
# hh_demographic.csv  100%[===================>]  43.31K   152KB/s    in 0.3s
#
# 2022-11-09 20:29:37 (152 KB/s) - ‘hh_demographic.csv’ saved [44349/44349]
#
# --2022-11-09 20:29:37--  https://getfile.dokpub.com/yandex/get/https://disk.yandex.ru/d/YGMKawk5FPzM4w
# Resolving getfile.dokpub.com (getfile.dokpub.com)... 142.132.255.217
# Connecting to getfile.dokpub.com (getfile.dokpub.com)|142.132.255.217|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://downloader.disk.yandex.ru/disk/230c43b2fc4d71a02b5c9d728aa87987ff89c88d0afae0d75e53373fd5683f1c/636c35dc/MNC-wvHOfDa0WFpeCBXdEaX24rqaVQ-dEkvoEfgAox5oydQdGQCWThv8cvgEyVrRD8XxOg5a1MAbYPNH5xYjZg%3D%3D?uid=0&filename=product.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZKMOgx67UUlyic9xBcbwCZR03Da7YP%2BlOWIkSDVTTYrBiyh0ufqrE%2B6HoJ72QHZn3Q%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=6429896&hid=6f079f534f35a1e50915edf0b0d60977&media_type=spreadsheet&tknv=v2 [following]
# --2022-11-09 20:29:38--  https://downloader.disk.yandex.ru/disk/230c43b2fc4d71a02b5c9d728aa87987ff89c88d0afae0d75e53373fd5683f1c/636c35dc/MNC-wvHOfDa0WFpeCBXdEaX24rqaVQ-dEkvoEfgAox5oydQdGQCWThv8cvgEyVrRD8XxOg5a1MAbYPNH5xYjZg%3D%3D?uid=0&filename=product.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZKMOgx67UUlyic9xBcbwCZR03Da7YP%2BlOWIkSDVTTYrBiyh0ufqrE%2B6HoJ72QHZn3Q%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=6429896&hid=6f079f534f35a1e50915edf0b0d60977&media_type=spreadsheet&tknv=v2
# Resolving downloader.disk.yandex.ru (downloader.disk.yandex.ru)... 77.88.21.127, 2a02:6b8::2:127
# Connecting to downloader.disk.yandex.ru (downloader.disk.yandex.ru)|77.88.21.127|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s362vla.storage.yandex.net/rdisk/230c43b2fc4d71a02b5c9d728aa87987ff89c88d0afae0d75e53373fd5683f1c/636c35dc/MNC-wvHOfDa0WFpeCBXdEaX24rqaVQ-dEkvoEfgAox5oydQdGQCWThv8cvgEyVrRD8XxOg5a1MAbYPNH5xYjZg==?uid=0&filename=product.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZKMOgx67UUlyic9xBcbwCZR03Da7YP%2BlOWIkSDVTTYrBiyh0ufqrE%2B6HoJ72QHZn3Q%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=6429896&hid=6f079f534f35a1e50915edf0b0d60977&media_type=spreadsheet&tknv=v2&rtoken=sz8c7gBQQVF9&force_default=no&ycrid=na-fe2bef48f6fd99e56cb124f342fa729f-downloader9e&ts=5ed11e8d42f00&s=c9de214cfdc06d15b50fd9b647b07bd8e8f831a819ad9aa557eef8bd0e93b024&pb=U2FsdGVkX19R5IrgNnkLj9JeYcBQPdlXpT0PPxyXG1gz78SSmLcx2-jcz-dNnfWrD_zy6j1eUpZ2jKIo_cOLPqqVfJqFKIphKIHTi1JNXpc [following]
# --2022-11-09 20:29:38--  https://s362vla.storage.yandex.net/rdisk/230c43b2fc4d71a02b5c9d728aa87987ff89c88d0afae0d75e53373fd5683f1c/636c35dc/MNC-wvHOfDa0WFpeCBXdEaX24rqaVQ-dEkvoEfgAox5oydQdGQCWThv8cvgEyVrRD8XxOg5a1MAbYPNH5xYjZg==?uid=0&filename=product.csv&disposition=attachment&hash=v53oKGpCiygFJ679NGHlZKMOgx67UUlyic9xBcbwCZR03Da7YP%2BlOWIkSDVTTYrBiyh0ufqrE%2B6HoJ72QHZn3Q%3D%3D%3A&limit=0&content_type=text%2Fplain&owner_uid=1130000061907806&fsize=6429896&hid=6f079f534f35a1e50915edf0b0d60977&media_type=spreadsheet&tknv=v2&rtoken=sz8c7gBQQVF9&force_default=no&ycrid=na-fe2bef48f6fd99e56cb124f342fa729f-downloader9e&ts=5ed11e8d42f00&s=c9de214cfdc06d15b50fd9b647b07bd8e8f831a819ad9aa557eef8bd0e93b024&pb=U2FsdGVkX19R5IrgNnkLj9JeYcBQPdlXpT0PPxyXG1gz78SSmLcx2-jcz-dNnfWrD_zy6j1eUpZ2jKIo_cOLPqqVfJqFKIphKIHTi1JNXpc
# Resolving s362vla.storage.yandex.net (s362vla.storage.yandex.net)... 141.8.128.86, 2a02:6b8:c0e:acd:0:41af:c3e3:2068
# Connecting to s362vla.storage.yandex.net (s362vla.storage.yandex.net)|141.8.128.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6429896 (6.1M) [text/plain]
# Saving to: ‘product.csv’
#
# product.csv         100%[===================>]   6.13M  4.76MB/s    in 1.3s
#
# 2022-11-09 20:29:41 (4.76 MB/s) - ‘product.csv’ saved [6429896/6429896]

# %%
data = pd.read_csv('retail_train.csv')
item_features = pd.read_csv('product.csv')
user_features = pd.read_csv('hh_demographic.csv')

#уменьшим датасет, не хватает памяти
data = data[:1000000]

# column processing
item_features.columns = [col.lower() for col in item_features.columns]
user_features.columns = [col.lower() for col in user_features.columns]

item_features.rename(columns={'product_id': 'item_id'}, inplace=True)
user_features.rename(columns={'household_key': 'user_id'}, inplace=True)


# Важна схема обучения и валидации: делим на трейн и тест
# -- давние покупки -- | -- 6 недель -- | -- 3 недель -- 
# подобрать размер 2-ого датасета (6 недель) --> learning curve (зависимость метрики recall@k от размера датасета)
val_lvl_1_size_weeks = 6
val_lvl_2_size_weeks = 3

data_train_lvl_1 = data[data['week_no'] < data['week_no'].max() - (val_lvl_1_size_weeks + val_lvl_2_size_weeks)]
data_val_lvl_1 = data[(data['week_no'] >= data['week_no'].max() - (val_lvl_1_size_weeks + val_lvl_2_size_weeks)) &
                      (data['week_no'] < data['week_no'].max() - (val_lvl_2_size_weeks))]

data_train_lvl_2 = data_val_lvl_1.copy() 
data_val_lvl_2 = data[data['week_no'] >= data['week_no'].max() - val_lvl_2_size_weeks]

data_train_lvl_1.head(12)
# Out:
#     user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0      2375  26984851472    1  1004906         1         1.39       364
# 1      2375  26984851472    1  1033142         1         0.82       364
# 2      2375  26984851472    1  1036325         1         0.99       364
# 3      2375  26984851472    1  1082185         1         1.21       364
# 4      2375  26984851472    1  8160430         1         1.50       364
# 5      2375  26984851516    1   826249         2         1.98       364
# 6      2375  26984851516    1  1043142         1         1.57       364
# 7      2375  26984851516    1  1085983         1         2.99       364
# 8      2375  26984851516    1  1102651         1         1.89       364
# 9      2375  26984851516    1  6423775         1         2.00       364
# 10     2375  26984851516    1  9487839         1         2.00       364
# 11     1364  26984896261    1   842930         1         2.19     31742
#
#     retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0         -0.60        1631        1          0.0                0.0
# 1          0.00        1631        1          0.0                0.0
# 2         -0.30        1631        1          0.0                0.0
# 3          0.00        1631        1          0.0                0.0
# 4         -0.39        1631        1          0.0                0.0
# 5         -0.60        1642        1          0.0                0.0
# 6         -0.68        1642        1          0.0                0.0
# 7         -0.40        1642        1          0.0                0.0
# 8          0.00        1642        1          0.0                0.0
# 9         -0.79        1642        1          0.0                0.0
# 10        -0.79        1642        1          0.0                0.0
# 11         0.00        1520        1          0.0                0.0

# %%
# будем использовать топ 5000 товаров (см src/MainRecommender)

n_items_before = data_train_lvl_1['item_id'].nunique()

data_train_lvl_1 = prefilter_items(data_train_lvl_1, item_features=item_features, take_n_popular=5000)

n_items_after = data_train_lvl_1['item_id'].nunique()
print('Decreased # items from {} to {}'.format(n_items_before, n_items_after))
# Out:
# Decreased # items from 52624 to 5001

# %%
# создаем Рекоммендер
recommender = MainRecommender(data_train_lvl_1)
# Out:
# /usr/local/lib/python3.7/dist-packages/implicit/utils.py:29: UserWarning: OpenBLAS detected. Its highly recommend to set the environment variable 'export OPENBLAS_NUM_THREADS=1' to disable its internal multithreading
#   "OpenBLAS detected. Its highly recommend to set the environment variable "
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/2479 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/implicit/utils.py:141: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.0013141632080078125 seconds
#   ParameterWarning,
#   0%|          | 0/2479 [00:00<?, ?it/s]

# %%
recommender

# %% [markdown]
# Получаем кандидатов. Если модель рекомендует < N товаров, то рекомендации дополняются топ-популярными товарами до N

# %%
recommender.get_als_recommendations(2375, N=5)
# Out:
# [1011457, 970866, 974524, 971922, 911565]

# %% [markdown]
# ### Измеряем recall@k
#
# - Качество измеряем на data_val_lvl_1: следующие 6 недель после трейна
#
# own recommendtions + top-popular лучший recall

# %%
result_lvl_1 = data_val_lvl_1.groupby('user_id')['item_id'].unique().reset_index()
result_lvl_1.columns=['user_id', 'actual']
result_lvl_1.head(2)
# Out:
#    user_id                                             actual
# 0        1  [843559, 856942, 871570, 888996, 928891, 93800...
# 1        2  [861272, 1116476, 12187999, 12188436, 12263180...

# %%
users_lvl_1 = pd.DataFrame(data_train_lvl_1['user_id'].unique())
users_lvl_1.columns = ['user_id']

# %%
K_num = 50
result_lvl_1['als_rec'] = users_lvl_1['user_id'].apply(lambda x: recommender.get_als_recommendations(x, N=K_num))

# %%
result_lvl_1.head(2)
# Out:
#    user_id                                             actual  \
# 0        1  [843559, 856942, 871570, 888996, 928891, 93800...
# 1        2  [861272, 1116476, 12187999, 12188436, 12263180...
#
#                                              als_rec
# 0  [1011457, 970866, 974524, 971922, 911565, 9683...
# 1  [921504, 909800, 1011427, 970202, 983897, 1011...

# %%
def calculate_precision_k(data, K): #data - pandas df
    for column in data.columns[2:]:
        yield column, data.apply(lambda row: precision_at_k(row[column], row['actual'], k=K), axis=1).mean()

# %%
# посмотрим precision_5
prec_K = 5
sorted(calculate_precision_k(result_lvl_1, prec_K), key=lambda x: x[1],reverse=True)
# Out:
# [('als_rec', 0.0036844591402928678)]

# %% [markdown]
# ### Обучаем модель 2-ого уровня на выбранных кандидатах
#
# - Обучаем на data_train_lvl_2
# - Обучаем *только* на выбранных кандидатах
# - (!) Если юзер купил < 50 товаров, то get_own_recommendations дополнит рекоммендации топ-популярными

# %%
# -- давние покупки -- | -- 6 недель -- | -- 3 недель --

# %%
users_lvl_2 = pd.DataFrame(data_train_lvl_2['user_id'].unique())
users_lvl_2.columns = ['user_id']

# Пока только warm start, фильтруем юзеров
train_users = data_train_lvl_1['user_id'].unique()
users_lvl_2 = users_lvl_2[users_lvl_2['user_id'].isin(train_users)]

users_lvl_2['candidates'] = users_lvl_2['user_id'].apply(lambda x: recommender.get_als_recommendations(x, N=50))

# %%
users_lvl_2.head(2)
# Out:
#    user_id                                         candidates
# 0      816  [999953, 956127, 920804, 1002178, 848107, 9337...
# 1     1375  [940726, 935993, 1012627, 879393, 887375, 8285...

# %%
s = users_lvl_2.apply(lambda x: pd.Series(x['candidates']), axis=1).stack().reset_index(level=1, drop=True)
s.name = 'item_id'

users_lvl_2 = users_lvl_2.drop('candidates', axis=1).join(s)
users_lvl_2['flag'] = 1

users_lvl_2.head(4)
# Out:
#    user_id  item_id  flag
# 0      816   999953     1
# 0      816   956127     1
# 0      816   920804     1
# 0      816  1002178     1

# %%
users_lvl_2.shape[0]
# Out:
# 105550

# %%
users_lvl_2['user_id'].nunique()
# Out:
# 2111

# %%
targets_lvl_2 = data_train_lvl_2[['user_id', 'item_id']].copy()
targets_lvl_2['target'] = 1  # тут только покупки 

targets_lvl_2 = users_lvl_2.merge(targets_lvl_2, on=['user_id', 'item_id'], how='left')

targets_lvl_2['target'].fillna(0, inplace= True)
targets_lvl_2.drop('flag', axis=1, inplace=True)

# %%
targets_lvl_2.shape
# Out:
# (105651, 3)

# %%
targets_lvl_2.head(2)
# Out:
#    user_id  item_id  target
# 0      816   999953     0.0
# 1      816   956127     0.0

# %%
targets_lvl_2['target'].value_counts()
# Out:
# 0.0    105016
# 1.0       635
# Name: target, dtype: int64

# %% [markdown]
# (!) На каждого юзера 50 item_id-кандидатов

# %%
item_features.head(2)
# Out:
#    item_id  manufacturer    department     brand            commodity_desc  \
# 0    25671             2       GROCERY  National                  FRZN ICE
# 1    26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
#
#             sub_commodity_desc curr_size_of_product
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION

# %%
user_features.head(2)
# Out:
#   age_desc marital_status_code income_desc homeowner_desc      hh_comp_desc  \
# 0      65+                   A      35-49K      Homeowner  2 Adults No Kids
# 1    45-54                   A      50-74K      Homeowner  2 Adults No Kids
#
#   household_size_desc kid_category_desc  user_id
# 0                   2      None/Unknown        1
# 1                   2      None/Unknown        7

# %%
#объединим все признаки в один датафрейм
targets_lvl_2 = targets_lvl_2.merge(item_features, on='item_id', how='left')
targets_lvl_2 = targets_lvl_2.merge(user_features, on='user_id', how='left')

targets_lvl_2.head(2)
# Out:
#    user_id  item_id  target  manufacturer department     brand commodity_desc  \
# 0      816   999953     0.0          1046    GROCERY  National    COLD CEREAL
# 1      816   956127     0.0           317    GROCERY  National         CHEESE
#
#                sub_commodity_desc curr_size_of_product age_desc  \
# 0                    ADULT CEREAL              13.5 OZ    25-34
# 1  NATURAL CHEESE EXACT WT SLICES                 8 OZ    25-34
#
#   marital_status_code income_desc homeowner_desc   hh_comp_desc  \
# 0                   U      50-74K        Unknown  Single Female
# 1                   U      50-74K        Unknown  Single Female
#
#   household_size_desc kid_category_desc
# 0                   1      None/Unknown
# 1                   1      None/Unknown

# %%
# объединим все в одну df для построения новых фичей
df_feach_eng = data[(data['week_no'] >= data['week_no'].max() - (val_lvl_1_size_weeks + val_lvl_2_size_weeks)) &
                      (data['week_no'] < data['week_no'].max() - (val_lvl_2_size_weeks))]

df_feach_eng = df_feach_eng.merge(item_features, on='item_id', how='left')
df_feach_eng = df_feach_eng.merge(user_features, on='user_id', how='left')
df_feach_eng.columns
# Out:
# Index(['user_id', 'basket_id', 'day', 'item_id', 'quantity', 'sales_value',
#        'store_id', 'retail_disc', 'trans_time', 'week_no', 'coupon_disc',
#        'coupon_match_disc', 'manufacturer', 'department', 'brand',
#        'commodity_desc', 'sub_commodity_desc', 'curr_size_of_product',
#        'age_desc', 'marital_status_code', 'income_desc', 'homeowner_desc',
#        'hh_comp_desc', 'household_size_desc', 'kid_category_desc'],
#       dtype='object')

# %%
# добавим фич и и для data_val_lvl_2(используем его для валидации модели)

df_val = data_val_lvl_2.copy()
df_val = df_val.merge(item_features, on='item_id', how='left')
df_val = df_val.merge(user_features, on='user_id', how='left')
df_val.columns
# Out:
# Index(['user_id', 'basket_id', 'day', 'item_id', 'quantity', 'sales_value',
#        'store_id', 'retail_disc', 'trans_time', 'week_no', 'coupon_disc',
#        'coupon_match_disc', 'manufacturer', 'department', 'brand',
#        'commodity_desc', 'sub_commodity_desc', 'curr_size_of_product',
#        'age_desc', 'marital_status_code', 'income_desc', 'homeowner_desc',
#        'hh_comp_desc', 'household_size_desc', 'kid_category_desc'],
#       dtype='object')

# %%
# готовим датасет для загрузки в классификатор
targets_lvl_2 = targets_lvl_2.merge(data_train_lvl_2, on='user_id', how='left')

# %%
targets_lvl_2.columns
# Out:
# Index(['user_id', 'item_id_x', 'target', 'manufacturer', 'department', 'brand',
#        'commodity_desc', 'sub_commodity_desc', 'curr_size_of_product',
#        'age_desc', 'marital_status_code', 'income_desc', 'homeowner_desc',
#        'hh_comp_desc', 'household_size_desc', 'kid_category_desc', 'basket_id',
#        'day', 'item_id_y', 'quantity', 'sales_value', 'store_id',
#        'retail_disc', 'trans_time', 'week_no', 'coupon_disc',
#        'coupon_match_disc'],
#       dtype='object')

# %%
# генерим новые фичи
# средний чек на юзера
df = df_feach_eng.groupby(['user_id', 'basket_id'])['sales_value'].sum().reset_index()
df = df.groupby('user_id')['sales_value'].mean().reset_index()
df.columns = ['user_id', 'avg_bill']
targets_lvl_2 = targets_lvl_2.merge(df, on='user_id')
targets_lvl_2.head(2)
# Out:
#    user_id  item_id_x  target  manufacturer department     brand  \
# 0      816     999953     0.0          1046    GROCERY  National
# 1      816     999953     0.0          1046    GROCERY  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product age_desc  ...  \
# 0    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
# 1    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
#
#   item_id_y quantity sales_value store_id retail_disc trans_time  week_no  \
# 0    869150        1        1.79      445       -0.04         32       37
# 1    883404        1        0.99      445       -0.30         32       37
#
#    coupon_disc  coupon_match_disc   avg_bill
# 0          0.0                0.0  36.756667
# 1          0.0                0.0  36.756667
#
# [2 rows x 28 columns]

# %%
df = df_val.groupby(['user_id', 'basket_id'])['sales_value'].sum().reset_index()
df = df.groupby('user_id')['sales_value'].mean().reset_index()
df.columns = ['user_id', 'avg_bill']
df_val = df_val.merge(df, on='user_id')
df_val.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2295  31336488347  293   822241         2          0.4       403
# 1     2295  31336488347  293   822524         2          3.0       403
#
#    retail_disc  trans_time  week_no  ...         sub_commodity_desc  \
# 0         0.00         117       43  ...  SOFT DRINK POWDER POUCHES
# 1        -1.58         117       43  ...                       TUNA
#
#    curr_size_of_product  age_desc marital_status_code income_desc  \
# 0                .17 OZ     35-44                   B      35-49K
# 1                 12 OZ     35-44                   B      35-49K
#
#   homeowner_desc hh_comp_desc household_size_desc kid_category_desc   avg_bill
# 0         Renter  Single Male                   1      None/Unknown  84.012857
# 1         Renter  Single Male                   1      None/Unknown  84.012857
#
# [2 rows x 26 columns]

# %%
#Кол-во покупок юзера в каждой категории
df = df_feach_eng.groupby(['user_id', 'department'])['quantity'].sum().reset_index()
df = df.groupby('user_id')['quantity'].mean().reset_index()
df.columns = ['user_id', 'avg_count_pursh_dep']
targets_lvl_2 = targets_lvl_2.merge(df, on='user_id')
targets_lvl_2.head(2)
# Out:
#    user_id  item_id_x  target  manufacturer department     brand  \
# 0      816     999953     0.0          1046    GROCERY  National
# 1      816     999953     0.0          1046    GROCERY  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product age_desc  ...  \
# 0    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
# 1    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
#
#   quantity sales_value store_id retail_disc trans_time week_no  coupon_disc  \
# 0        1        1.79      445       -0.04         32      37          0.0
# 1        1        0.99      445       -0.30         32      37          0.0
#
#    coupon_match_disc   avg_bill  avg_count_pursh_dep
# 0                0.0  36.756667            21.714286
# 1                0.0  36.756667            21.714286
#
# [2 rows x 29 columns]

# %%
df = df_val.groupby(['user_id', 'department'])['quantity'].sum().reset_index()
df = df.groupby('user_id')['quantity'].mean().reset_index()
df.columns = ['user_id', 'avg_count_pursh_dep']
df_val = df_val.merge(df, on='user_id')
df_val.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2295  31336488347  293   822241         2          0.4       403
# 1     2295  31336488347  293   822524         2          3.0       403
#
#    retail_disc  trans_time  week_no  ...  curr_size_of_product  age_desc  \
# 0         0.00         117       43  ...                .17 OZ     35-44
# 1        -1.58         117       43  ...                 12 OZ     35-44
#
#    marital_status_code income_desc homeowner_desc hh_comp_desc  \
# 0                    B      35-49K         Renter  Single Male
# 1                    B      35-49K         Renter  Single Male
#
#   household_size_desc kid_category_desc   avg_bill avg_count_pursh_dep
# 0                   1      None/Unknown  84.012857              36.375
# 1                   1      None/Unknown  84.012857              36.375
#
# [2 rows x 27 columns]

# %% [markdown]
# Фичи item_id: - Кол-во покупок в неделю - Среднее ол-во покупок 1 товара в категории в неделю - (Кол-во покупок в неделю) / (Среднее ол-во покупок 1 товара в категории в неделю) - Цена (Можно посчитать из retil_train.csv) - Цена / Средняя цена товара в категории

# %%
# Среднее кол-во покупок 1 товара в категории
df = df_feach_eng.groupby(['item_id', 'department'])['quantity'].sum().reset_index()
df = df.groupby('item_id')['quantity'].mean().reset_index()
df.columns = ['item_id_x', 'avg_count_item_dep']
targets_lvl_2 = targets_lvl_2.merge(df, on='item_id_x')
targets_lvl_2.head(2)
# Out:
#    user_id  item_id_x  target  manufacturer department     brand  \
# 0      816     999953     0.0          1046    GROCERY  National
# 1      816     999953     0.0          1046    GROCERY  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product age_desc  ...  \
# 0    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
# 1    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
#
#   sales_value store_id retail_disc trans_time week_no coupon_disc  \
# 0        1.79      445       -0.04         32      37         0.0
# 1        0.99      445       -0.30         32      37         0.0
#
#    coupon_match_disc   avg_bill  avg_count_pursh_dep  avg_count_item_dep
# 0                0.0  36.756667            21.714286                 5.0
# 1                0.0  36.756667            21.714286                 5.0
#
# [2 rows x 30 columns]

# %%
df = df_val.groupby(['item_id', 'department'])['quantity'].sum().reset_index()
df = df.groupby('item_id')['quantity'].mean().reset_index()
df.columns = ['item_id', 'avg_count_item_dep']
df_val = df_val.merge(df, on='item_id')
df_val.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2295  31336488347  293   822241         2          0.4       403
# 1      955  31343676130  293   822241         2          0.4       367
#
#    retail_disc  trans_time  week_no  ...  age_desc  marital_status_code  \
# 0          0.0         117       43  ...     35-44                    B
# 1          0.0        1943       43  ...     19-24                    U
#
#    income_desc homeowner_desc   hh_comp_desc household_size_desc  \
# 0       35-49K         Renter    Single Male                   1
# 1    Under 15K        Unknown  Single Female                   1
#
#   kid_category_desc   avg_bill avg_count_pursh_dep avg_count_item_dep
# 0      None/Unknown  84.012857              36.375               37.0
# 1      None/Unknown  20.090000              18.400               37.0
#
# [2 rows x 28 columns]

# %%
#цена товара
targets_lvl_2['price'] = targets_lvl_2['sales_value']/targets_lvl_2['quantity']
targets_lvl_2.head(2)
# Out:
#    user_id  item_id_x  target  manufacturer department     brand  \
# 0      816     999953     0.0          1046    GROCERY  National
# 1      816     999953     0.0          1046    GROCERY  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product age_desc  ...  \
# 0    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
# 1    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
#
#   store_id retail_disc trans_time week_no coupon_disc coupon_match_disc  \
# 0      445       -0.04         32      37         0.0               0.0
# 1      445       -0.30         32      37         0.0               0.0
#
#     avg_bill  avg_count_pursh_dep  avg_count_item_dep  price
# 0  36.756667            21.714286                 5.0   1.79
# 1  36.756667            21.714286                 5.0   0.99
#
# [2 rows x 31 columns]

# %%
df_val['price'] = df_val['sales_value']/df_val['quantity']
df_val.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2295  31336488347  293   822241         2          0.4       403
# 1      955  31343676130  293   822241         2          0.4       367
#
#    retail_disc  trans_time  week_no  ...  marital_status_code  income_desc  \
# 0          0.0         117       43  ...                    B       35-49K
# 1          0.0        1943       43  ...                    U    Under 15K
#
#    homeowner_desc   hh_comp_desc household_size_desc kid_category_desc  \
# 0          Renter    Single Male                   1      None/Unknown
# 1         Unknown  Single Female                   1      None/Unknown
#
#     avg_bill avg_count_pursh_dep avg_count_item_dep price
# 0  84.012857              36.375               37.0   0.2
# 1  20.090000              18.400               37.0   0.2
#
# [2 rows x 29 columns]

# %% [markdown]
# Фичи пары user_id - item_id - (Средняя сумма покупки 1 товара в каждой категории (берем категорию item_id)) - (Цена item_id) - (Кол-во покупок юзером конкретной категории в неделю) - (Среднее кол-во покупок всеми юзерами конкретной категории в неделю) - (Кол-во покупок юзером конкретной категории в неделю) / (Среднее кол-во покупок всеми юзерами конкретной категории в неделю)

# %%
# Среднее кол-во покупок всеми юзерами конкретной категории в неделю
df = df_feach_eng.groupby(['department', 'week_no'])['quantity'].sum().reset_index()
df = df.groupby('department')['quantity'].mean().reset_index()
df.columns = ['department', 'avg_sum_all_pursh_dep']
targets_lvl_2 = targets_lvl_2.merge(df, on='department')
targets_lvl_2.head(2)
# Out:
#    user_id  item_id_x  target  manufacturer department     brand  \
# 0      816     999953     0.0          1046    GROCERY  National
# 1      816     999953     0.0          1046    GROCERY  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product age_desc  ...  \
# 0    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
# 1    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
#
#   retail_disc trans_time week_no coupon_disc coupon_match_disc   avg_bill  \
# 0       -0.04         32      37         0.0               0.0  36.756667
# 1       -0.30         32      37         0.0               0.0  36.756667
#
#    avg_count_pursh_dep  avg_count_item_dep  price  avg_sum_all_pursh_dep
# 0            21.714286                 5.0   1.79           24758.333333
# 1            21.714286                 5.0   0.99           24758.333333
#
# [2 rows x 32 columns]

# %%
df = df_val.groupby(['department', 'week_no'])['quantity'].sum().reset_index()
df = df.groupby('department')['quantity'].mean().reset_index()
df.columns = ['department', 'avg_sum_all_pursh_dep']
df_val = df_val.merge(df, on='department')
df_val.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2295  31336488347  293   822241         2          0.4       403
# 1      955  31343676130  293   822241         2          0.4       367
#
#    retail_disc  trans_time  week_no  ...  income_desc  homeowner_desc  \
# 0          0.0         117       43  ...       35-49K          Renter
# 1          0.0        1943       43  ...    Under 15K         Unknown
#
#     hh_comp_desc household_size_desc kid_category_desc   avg_bill  \
# 0    Single Male                   1      None/Unknown  84.012857
# 1  Single Female                   1      None/Unknown  20.090000
#
#   avg_count_pursh_dep avg_count_item_dep price avg_sum_all_pursh_dep
# 0              36.375               37.0   0.2               20717.5
# 1              18.400               37.0   0.2               20717.5
#
# [2 rows x 30 columns]

# %%
# (Кол-во покупок юзером конкретной категории в неделю) / (Среднее кол-во покупок всеми юзерами конкретной категории в неделю)

targets_lvl_2['user_count_per_dep_pursh'] = targets_lvl_2['avg_count_pursh_dep']/targets_lvl_2['avg_sum_all_pursh_dep']
targets_lvl_2.head(2)
# Out:
#    user_id  item_id_x  target  manufacturer department     brand  \
# 0      816     999953     0.0          1046    GROCERY  National
# 1      816     999953     0.0          1046    GROCERY  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product age_desc  ...  \
# 0    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
# 1    COLD CEREAL       ADULT CEREAL              13.5 OZ    25-34  ...
#
#   trans_time week_no coupon_disc coupon_match_disc   avg_bill  \
# 0         32      37         0.0               0.0  36.756667
# 1         32      37         0.0               0.0  36.756667
#
#   avg_count_pursh_dep  avg_count_item_dep  price  avg_sum_all_pursh_dep  \
# 0           21.714286                 5.0   1.79           24758.333333
# 1           21.714286                 5.0   0.99           24758.333333
#
#    user_count_per_dep_pursh
# 0                  0.000877
# 1                  0.000877
#
# [2 rows x 33 columns]

# %%
df_val['user_count_per_dep_pursh'] = df_val['avg_count_pursh_dep']/df_val['avg_sum_all_pursh_dep']
df_val.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2295  31336488347  293   822241         2          0.4       403
# 1      955  31343676130  293   822241         2          0.4       367
#
#    retail_disc  trans_time  week_no  ...  homeowner_desc   hh_comp_desc  \
# 0          0.0         117       43  ...          Renter    Single Male
# 1          0.0        1943       43  ...         Unknown  Single Female
#
#    household_size_desc kid_category_desc   avg_bill avg_count_pursh_dep  \
# 0                    1      None/Unknown  84.012857              36.375
# 1                    1      None/Unknown  20.090000              18.400
#
#   avg_count_item_dep price avg_sum_all_pursh_dep user_count_per_dep_pursh
# 0               37.0   0.2               20717.5                 0.001756
# 1               37.0   0.2               20717.5                 0.000888
#
# [2 rows x 31 columns]

# %%
X_train = targets_lvl_2.drop('target', axis=1)
y_train = targets_lvl_2[['target']]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7997691 entries, 0 to 7997690
# Data columns (total 32 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   user_id                   int64
#  1   item_id_x                 int64
#  2   manufacturer              int64
#  3   department                object
#  4   brand                     object
#  5   commodity_desc            object
#  6   sub_commodity_desc        object
#  7   curr_size_of_product      object
#  8   age_desc                  object
#  9   marital_status_code       object
#  10  income_desc               object
#  11  homeowner_desc            object
#  12  hh_comp_desc              object
#  13  household_size_desc       object
#  14  kid_category_desc         object
#  15  basket_id                 int64
#  16  day                       int64
#  17  item_id_y                 int64
#  18  quantity                  int64
#  19  sales_value               float64
#  20  store_id                  int64
#  21  retail_disc               float64
#  22  trans_time                int64
#  23  week_no                   int64
#  24  coupon_disc               float64
#  25  coupon_match_disc         float64
#  26  avg_bill                  float64
#  27  avg_count_pursh_dep       float64
#  28  avg_count_item_dep        float64
#  29  price                     float64
#  30  avg_sum_all_pursh_dep     float64
#  31  user_count_per_dep_pursh  float64
# dtypes: float64(10), int64(10), object(12)
# memory usage: 2.0+ GB

# %%
X_train = X_train.drop('item_id_y', axis=1)
X_train.columns.tolist()
# Out:
# ['user_id',
#  'item_id_x',
#  'manufacturer',
#  'department',
#  'brand',
#  'commodity_desc',
#  'sub_commodity_desc',
#  'curr_size_of_product',
#  'age_desc',
#  'marital_status_code',
#  'income_desc',
#  'homeowner_desc',
#  'hh_comp_desc',
#  'household_size_desc',
#  'kid_category_desc',
#  'basket_id',
#  'day',
#  'quantity',
#  'sales_value',
#  'store_id',
#  'retail_disc',
#  'trans_time',
#  'week_no',
#  'coupon_disc',
#  'coupon_match_disc',
#  'avg_bill',
#  'avg_count_pursh_dep',
#  'avg_count_item_dep',
#  'price',
#  'avg_sum_all_pursh_dep',
#  'user_count_per_dep_pursh']

# %%
df_val = df_val.rename(columns={'item_id': 'item_id_x'})
df_val.columns.tolist()
# Out:
# ['user_id',
#  'basket_id',
#  'day',
#  'item_id_x',
#  'quantity',
#  'sales_value',
#  'store_id',
#  'retail_disc',
#  'trans_time',
#  'week_no',
#  'coupon_disc',
#  'coupon_match_disc',
#  'manufacturer',
#  'department',
#  'brand',
#  'commodity_desc',
#  'sub_commodity_desc',
#  'curr_size_of_product',
#  'age_desc',
#  'marital_status_code',
#  'income_desc',
#  'homeowner_desc',
#  'hh_comp_desc',
#  'household_size_desc',
#  'kid_category_desc',
#  'avg_bill',
#  'avg_count_pursh_dep',
#  'avg_count_item_dep',
#  'price',
#  'avg_sum_all_pursh_dep',
#  'user_count_per_dep_pursh']

# %%
cat_feats =['department',
 'brand',
 'commodity_desc',
 'sub_commodity_desc',
 'curr_size_of_product',
 'age_desc',
 'marital_status_code',
 'income_desc',
 'homeowner_desc',
 'hh_comp_desc',
 'household_size_desc',
 'kid_category_desc']

# %%
for c in cat_feats:
    
    X_train[c] = X_train[c].astype('category')

# %%
for c in cat_feats:
    
    df_val[c] = df_val[c].astype('category')

# %%
lgb = LGBMClassifier(objective='binary',
                     max_depth=8,
                     n_estimators=300,
                     learning_rate=0.05,
                     categorical_column=cat_feats)

lgb.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# LGBMClassifier(categorical_column=['department', 'brand', 'commodity_desc',
#                                    'sub_commodity_desc', 'curr_size_of_product',
#                                    'age_desc', 'marital_status_code',
#                                    'income_desc', 'homeowner_desc',
#                                    'hh_comp_desc', 'household_size_desc',
#                                    'kid_category_desc'],
#                learning_rate=0.05, max_depth=8, n_estimators=300,
#                objective='binary')

# %%
train_preds = lgb.predict(X_train)

# %%
train_preds
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
val_preds = lgb.predict_proba(df_val)

# %%
val_preds
# Out:
# array([[9.99798436e-01, 2.01563683e-04],
#        [9.98841265e-01, 1.15873465e-03],
#        [9.99677894e-01, 3.22105500e-04],
#        ...,
#        [9.99878216e-01, 1.21784337e-04],
#        [9.99393894e-01, 6.06106325e-04],
#        [9.99955155e-01, 4.48447651e-05]])

# %%
result_lvl_2 = data_val_lvl_2.groupby('user_id')['item_id'].unique().reset_index()
result_lvl_2.columns=['user_id', 'actual']
result_lvl_2.head(2)
# Out:
#    user_id                                             actual
# 0        1  [835796, 856942, 858450, 918390, 934369, 94094...
# 1        3                         [892920, 1092502, 1119761]

# %%
pred_ds = df_val[['user_id', 'item_id_x']].copy()
pred_ds['proba'] = val_preds[:,1]
pred_ds = pred_ds.groupby(['user_id', 'item_id_x'])['proba'].mean().reset_index()
pred_s = pred_ds.groupby('user_id').apply(lambda x: x.sort_values('proba', ascending=False)['item_id_x'].tolist())

def get_LGBM_recommendations(user_id, N=5):
    recommendations = pred_s[user_id][:N]
    
    overall_top_purchases = data_val_lvl_2.groupby('item_id')['quantity'].count().reset_index()
    overall_top_purchases.sort_values('quantity', ascending=False, inplace=True)
    overall_top_purchases = overall_top_purchases[overall_top_purchases['item_id'] != 999999]
    overall_top_purchases = overall_top_purchases.item_id.tolist()
    
    if len(recommendations) < N:
            recommendations.extend(overall_top_purchases[:N])
            recommendations = recommendations[:N]
    
    return recommendations

# %%
users_lvl_2 = pd.DataFrame(data_train_lvl_2['user_id'].unique())
users_lvl_2.columns = ['user_id']


#только warm start
train_users = data_train_lvl_1['user_id'].unique()
users_lvl_2 = users_lvl_2[users_lvl_2['user_id'].isin(train_users)]

K_num = 50
result_lvl_2['LGBM'] = result_lvl_2['user_id'].apply(lambda x: get_LGBM_recommendations(x, N=K_num))

# %%
result_lvl_2.head(2)
# Out:
#    user_id                                             actual  \
# 0        1  [835796, 856942, 858450, 918390, 934369, 94094...
# 1        3                         [892920, 1092502, 1119761]
#
#                                                 LGBM
# 0  [995242, 1077490, 1074612, 1018600, 934369, 92...
# 1  [892920, 1119761, 1092502, 1082185, 6534178, 1...

# %%
def calculate_precision_k(data, K): #data - pandas df
    for column in data.columns[2:]:
        yield column, data.apply(lambda row: precision_at_k(row[column], row['actual'], k=K), axis=1).mean()

# %%
# Посчитаем precision_5 LGBM  
sorted(calculate_precision_k(result_lvl_2, 5), key=lambda x: x[1],reverse=True)
# Out:
# [('LGBM', 0.9529039070749735)]

# %%
# inference - получение 50 рекомендаций для одного юзера
# номер юзера - 23
output = get_LGBM_recommendations(23, N=50) #inference
output
# Out:
# [981760,
#  6534178,
#  909338,
#  982009,
#  1033062,
#  10200444,
#  1000329,
#  1053690,
#  1065593,
#  822407,
#  908846,
#  976998,
#  931777,
#  971325,
#  1110695,
#  7441668,
#  828331,
#  1084423,
#  1000728,
#  1138858,
#  1076306,
#  908408,
#  1135552,
#  907647,
#  926233,
#  1053022,
#  9831557,
#  1096290,
#  959737,
#  958023,
#  888783,
#  983710,
#  930331,
#  1047316,
#  833754,
#  6552995,
#  10457385,
#  5567705,
#  8119156,
#  997112,
#  1131490,
#  885261,
#  1101910,
#  1046201,
#  1064798,
#  1082185,
#  6534178,
#  1029743,
#  995242,
#  1106523]

# %%
# переведем полученные id товаров в группы товаров

# %%
def commodity_name(list_id):
  list_id = list(list_id)
  res = []
  for id in list_id:
    try:
      name = df_feach_eng.commodity_desc.loc[df_feach_eng.item_id == id]
      name = name.iloc[0]
      if name:
        res.append(name)
    except:
        pass
  res = np.array(res)
  return res

# %%
# то, что купил user
real = result_lvl_2.actual.loc[result_lvl_2.user_id == 23]
real = real.iloc[0]
commodity_name(np.sort(real))
# Out:
# array(['MEAT - SHELF STABLE', 'FROZEN PIZZA', 'FROZEN PIZZA',
#        'DOMESTIC WINE', 'DEODORANTS', 'BAKED BREAD/BUNS/ROLLS', 'CHEESE',
#        'CITRUS', 'REFRGRATD DOUGH PRODUCTS', 'COOKIES/CONES',
#        'BROOMS AND MOPS', 'MEAT - SHELF STABLE', 'BEERS/ALES',
#        'BEERS/ALES', 'CONDIMENTS/SAUCES', 'PAPER TOWELS', 'EGGS',
#        'PICKLE/RELISH/PKLD VEG', 'FROZEN PIZZA', 'CRACKERS/MISC BKD FD',
#        'FRZN VEGETABLE/VEG DSH', 'SOUP', 'LUNCHMEAT',
#        'STATIONERY & SCHOOL SUPPLIES', 'BEERS/ALES', 'SOFT DRINKS',
#        'ORAL HYGIENE PRODUCTS', 'BATH TISSUES', 'FROZEN PIZZA',
#        'CRACKERS/MISC BKD FD', 'BEERS/ALES', 'FRZN POTATOES', 'PROCESSED',
#        'COLD CEREAL', 'FROZEN PIZZA', 'FROZEN MEAT', 'COUPON/MISC ITEMS',
#        'CHEESE', 'BAG SNACKS', 'FROZEN PIZZA', 'COFFEE', 'BREAD',
#        'AIR CARE'], dtype='<U28')

# %%
# то, что предсказала модель
lgbm_rec = result_lvl_2.LGBM.loc[result_lvl_2.user_id == 23]
lgbm_rec = lgbm_rec.iloc[0]
commodity_name(np.sort(lgbm_rec))
# Out:
# array(['MEAT - SHELF STABLE', 'FROZEN PIZZA', 'FROZEN PIZZA',
#        'DOMESTIC WINE', 'DEODORANTS', 'BAKED BREAD/BUNS/ROLLS', 'CHEESE',
#        'CITRUS', 'REFRGRATD DOUGH PRODUCTS', 'COOKIES/CONES',
#        'BROOMS AND MOPS', 'MEAT - SHELF STABLE', 'BEERS/ALES',
#        'BEERS/ALES', 'CONDIMENTS/SAUCES', 'PAPER TOWELS', 'EGGS',
#        'PICKLE/RELISH/PKLD VEG', 'FLUID MILK PRODUCTS', 'FROZEN PIZZA',
#        'CRACKERS/MISC BKD FD', 'FRZN VEGETABLE/VEG DSH',
#        'FLUID MILK PRODUCTS', 'SOUP', 'LUNCHMEAT',
#        'STATIONERY & SCHOOL SUPPLIES', 'BEERS/ALES', 'SOFT DRINKS',
#        'ORAL HYGIENE PRODUCTS', 'BATH TISSUES', 'FROZEN PIZZA',
#        'TROPICAL FRUIT', 'CRACKERS/MISC BKD FD', 'BEERS/ALES',
#        'FLUID MILK PRODUCTS', 'FRZN POTATOES', 'PROCESSED', 'COLD CEREAL',
#        'FROZEN PIZZA', 'FROZEN MEAT', 'COUPON/MISC ITEMS',
#        'COUPON/MISC ITEMS', 'CHEESE', 'BAG SNACKS', 'FROZEN PIZZA',
#        'COFFEE', 'BREAD', 'AIR CARE'], dtype='<U28')
